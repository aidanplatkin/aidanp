# %%
import matplotlib.pyplot as plt
my_file = open("/Users/aidanplatkin/numbers.txt", "r")
content = my_file.read()
print(content)
content_list = content.split(",")
my_file.close()
#print(content_list)
content_list = [int(x) for x in content_list]
content_list.sort()
#print(content_list)

freq = {} 
for item in content_list: 
        if (item in freq): 
            freq[item] += 1
        else: 
            freq[item] = 1
for k, v in freq.items(): print(k, v)

    
x = content_list
plt.hist(x) 
plt.title("Frequency",)
plt.show()

import json

y=json.dumps(freq)
print(y)
# Out:
# 2,4,6,8,4,5,2,1,9,0,4,6,7,4,3,2,1,9,10,3,7,9,6,0,1,3,5,6,7,8,9,10,2,3,6,8,9,10,6,7,4,3,2,1,9,10,3,7,9,6,0,1,3,5,6,7,8,9,10,2,3,6,8,9,10,2,4,6,8,4,5,2,1,9,0,4,6,7,4,3,2,1,9,10,3,7,9,6,4,5,2,1,9,0,4,6,7,4,3,2,1,9,10,3,7,9,6,0,1,3,5,6,7,8,9,10,2,3,6,8,9,10,6,7,4,3,6,8,4,5,2,10,3,7,9,6,0,1,3,5,6,7,8,9,10,2,3,6,8,9,10,2,4,6,8,4,5,2,1,9,0,4,6,7,4,2,4,6,8,4,5,2,1,9,0,4,6,7,4,3,2,1,9,10,3,7,9,6
# 0 9
# 1 14
# 2 19
# 3 20
# 4 22
# 5 10
# 6 26
# 7 17
# 8 13
# 9 24
# 10 14
# {"0": 9, "1": 14, "2": 19, "3": 20, "4": 22, "5": 10, "6": 26, "7": 17, "8": 13, "9": 24, "10": 14}

# %%
new = open("/Users/aidanplatkin/testjson.json", "x")

# %%
new.write(y)
new.close()

# %%
import pandas as pd
df=pd.read_csv('/Users/aidanplatkin/amazon-orders.csv')

# %%
print(df)
# Out:
#    Order Date             Order ID Payment Instrument Type     Website  \
# 0  2019-04-01  112-0000000-0000001             Visa - 0001  Amazon.com
# 1  2019-04-01  112-0000000-0000002             Visa - 0001  Amazon.com
# 2  2019-04-01  112-0000000-0000003             Visa - 0001  Amazon.com
# 3  2019-04-04  112-0000000-0000004             Visa - 0001  Amazon.com
# 4  2019-04-05  112-0000000-0000005             Visa - 0001  Amazon.com
# 5  2019-04-05  112-0000000-0000006             Visa - 0001  Amazon.com
# 6  2019-04-07  112-0000000-0000007             Visa - 0001  Amazon.com
# 7  2019-04-08  112-0000000-0000008             Visa - 0001  Amazon.com
# 8  2019-04-20  112-0000000-0000009             Visa - 0001  Amazon.com
# 9  2019-04-23  112-0000000-0000010             Visa - 0001  Amazon.com
# 10 2019-05-05  112-0000000-0000011             Visa - 0001  Amazon.com
# 11 2019-05-06  112-0000000-0000012             Visa - 0001  Amazon.com
# ...

# %%
df = df.fillna(0)
df.head()
# Out:
#   Order Date             Order ID Payment Instrument Type     Website  \
# 0   04/01/19  112-0000000-0000001             Visa - 0001  Amazon.com
# 1   04/01/19  112-0000000-0000002             Visa - 0001  Amazon.com
# 2   04/01/19  112-0000000-0000003             Visa - 0001  Amazon.com
# 3   04/04/19  112-0000000-0000004             Visa - 0001  Amazon.com
# 4   04/05/19  112-0000000-0000005             Visa - 0001  Amazon.com
#
#    Purchase Order Number Ordering Customer Email Shipment Date  \
# 0                    0.0    your_email@gmail.com      04/01/19
# 1                    0.0    your_email@gmail.com      04/01/19
# 2                    0.0    your_email@gmail.com      04/01/19
# 3                    0.0    your_email@gmail.com      04/05/19
# 4                    0.0    your_email@gmail.com      04/07/19
#
#   Shipping Address Name Shipping Address Street 1  Shipping Address Street 2  \
# 0             Your Name             1 YOUR STREET                        0.0
# ...

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df.head()
# Out:
#   Order Date             Order ID Payment Instrument Type     Website  \
# 0 2019-04-01  112-0000000-0000001             Visa - 0001  Amazon.com
# 1 2019-04-01  112-0000000-0000002             Visa - 0001  Amazon.com
# 2 2019-04-01  112-0000000-0000003             Visa - 0001  Amazon.com
# 3 2019-04-04  112-0000000-0000004             Visa - 0001  Amazon.com
# 4 2019-04-05  112-0000000-0000005             Visa - 0001  Amazon.com
#
#    Purchase Order Number Ordering Customer Email Shipment Date  \
# 0                    0.0    your_email@gmail.com      04/01/19
# 1                    0.0    your_email@gmail.com      04/01/19
# 2                    0.0    your_email@gmail.com      04/01/19
# 3                    0.0    your_email@gmail.com      04/05/19
# 4                    0.0    your_email@gmail.com      04/07/19
#
#   Shipping Address Name Shipping Address Street 1  Shipping Address Street 2  \
# 0             Your Name             1 YOUR STREET                        0.0
# ...

# %%
del df["Website"]

# %%
del df["Purchase Order Number"]

# %%
del df["Ordering Customer Email"]

# %%
del df["Shipment Date"]

# %%
del df["Shipping Address Name"]

# %%
df.drop(['Shipping Address Street 1'], axis = 1)
# Out:
#    Order Date  Shipping Address Street 2 Shipping Address City  \
# 0  2019-04-01                        0.0               ANYTOWN
# 1  2019-04-01                        0.0               ANYTOWN
# 2  2019-04-01                        0.0               ANYTOWN
# 3  2019-04-04                        0.0               ANYTOWN
# 4  2019-04-05                        0.0               ANYTOWN
# 5  2019-04-05                        0.0               ANYTOWN
# 6  2019-04-07                        0.0               ANYTOWN
# 7  2019-04-08                        0.0               ANYTOWN
# 8  2019-04-20                        0.0               ANYTOWN
# 9  2019-04-23                        0.0               ANYTOWN
# 10 2019-05-05                        0.0               ANYTOWN
# 11 2019-05-06                        0.0               ANYTOWN
# 12 2019-05-10                        0.0               ANYTOWN
# 13 2019-05-14                        0.0               ANYTOWN
# ...

# %%
df.drop(["Shipping Address Street 1", "Shipping Address Street 2", "Order Status", "Carrier Name & Tracking Number", "Subtotal", "Shipping Charge", "Tax Before Promotions"], axis =1)
# Out:
#    Order Date Shipping Address City Shipping Address State  \
# 0  2019-04-01               ANYTOWN                     ME
# 1  2019-04-01               ANYTOWN                     ME
# 2  2019-04-01               ANYTOWN                     ME
# 3  2019-04-04               ANYTOWN                     ME
# 4  2019-04-05               ANYTOWN                     ME
# 5  2019-04-05               ANYTOWN                     ME
# 6  2019-04-07               ANYTOWN                     ME
# 7  2019-04-08               ANYTOWN                     ME
# 8  2019-04-20               ANYTOWN                     ME
# 9  2019-04-23               ANYTOWN                     ME
# 10 2019-05-05               ANYTOWN                     ME
# 11 2019-05-06               ANYTOWN                     ME
# 12 2019-05-10               ANYTOWN                     ME
# 13 2019-05-14               ANYTOWN                     ME
# 14 2019-05-18               ANYTOWN                     ME
# ...

# %%
df.drop(["Shipping Address Street 1", "Shipping Address Street 2", 
         "Order Status", "Carrier Name & Tracking Number", "Subtotal",
         "Shipping Charge", "Tax Before Promotions", "Total Promotions",
         "Tax Charged", "Buyer Name", "Group Name", 
         "Shipping Address City", "Shipping Address State",
         "Shipping Address Zip"], axis=1)
# Out:
#    Order Date  Total Charged
# 0  2019-04-01          36.93
# 1  2019-04-01          16.99
# 2  2019-04-01           9.99
# 3  2019-04-04         156.12
# 4  2019-04-05          14.99
# 5  2019-04-05          12.65
# 6  2019-04-07          40.63
# 7  2019-04-08          44.99
# 8  2019-04-20          28.80
# 9  2019-04-23          37.08
# 10 2019-05-05          12.99
# 11 2019-05-06           7.60
# 12 2019-05-10          27.99
# 13 2019-05-14          16.16
# 14 2019-05-18          10.50
# 15 2019-05-19          38.89
# 16 2019-05-21           9.44
# 17 2019-05-21          12.99
# 18 2019-05-21           7.99
# 19 2019-05-22          17.91
# 20 2019-05-22          36.92
# 21 2019-05-22           7.91
# 22 2019-05-24           7.67
# 23 2019-05-25           9.80
# 24 2019-05-28          13.95
# 25 2019-05-29           9.99
# 26 2019-05-30          11.58
# 27 2019-05-30          33.80
# 28 2019-06-03          28.99
# 29 2019-06-03          13.88
# 30 2019-06-05          12.26
# ...

# %%
Monthlysum=df.groupby(pd.Grouper(key='Order Date', axis=0, 
                      freq='M')).sum()

# %%
print(Monthlysum)
# Out:
#             Shipping Address Street 2  Total Charged  Group Name
# Order Date
# 2019-04-30                        0.0         399.17         0.0
# 2019-05-31                        0.0         294.08         0.0
# 2019-06-30                        0.0         130.35         0.0
# 2019-07-31                        0.0         954.13         0.0

# %%
Monthlymean=df.groupby(pd.Grouper(key='Order Date', axis=0, 
                      freq='M')).mean()

# %%
print(Monthlymean)
# Out:
#             Shipping Address Street 2  Total Charged  Group Name
# Order Date
# 2019-04-30                        0.0      39.917000         0.0
# 2019-05-31                        0.0      16.337778         0.0
# 2019-06-30                        0.0      21.725000         0.0
# 2019-07-31                        0.0      38.165200         0.0

# %%
print(Weeklymean)
# Out:
#             Shipping Address Street 2  Total Charged  Group Name
# Order Date
# 2019-04-30                        0.0      39.917000         0.0
# 2019-05-31                        0.0      16.337778         0.0
# 2019-06-30                        0.0      21.725000         0.0
# 2019-07-31                        0.0      38.165200         0.0

# %%
df["Total Charged"].sum()
# Out:
# 30.131016949152542

# %%
df["Total Charged"].mean()
# Out:
# 30.131016949152542

# %%
df["Total Charged"].max()
# Out:
# 210.99

# %%
df["Total Charged"].min()
# Out:
# 1.04

# %%
df["Total Charged"].std()
# Out:
# 36.42273246651456

# %%
df["Total Charged"].median()
# Out:
# 15.95

# %%
Monthlysum.groupby(['Order Date']).sum().plot(kind='pie', y='Total Charged', title= "Percentage of Total Spending by Month", autopct='%1.0f%%').legend(loc='center left',bbox_to_anchor=(1.0, 0.5));

# %%
Monthlymean.groupby(['Order Date']).sum().plot(kind='bar',y='Total Charged', title='Average Spent per Month').legend(loc='center left',bbox_to_anchor=(1.0, 0.5));
